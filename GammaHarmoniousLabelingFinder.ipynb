# %%
import GammaHarmoniousLabelingFinder as ghlf
import networkx as nx

if __name__ == '__main__':
    graph = nx.cycle_graph(9)
    nx.draw_kamada_kawai(graph)
    
    mods = (3,3)
    
    labels = ghlf._get_labeling_set(mods)
    
    ghlf.get_labeling(graph,labels,mods)
    ghlf.get_all_labelings(graph,labels,mods)
# Out:
# Getting a single labeling for the graph +hh+c+g+g+e@.g6
# Valid labeling found!
# {0: (0, 0), 1: (0, 1), 2: (1, 1), 3: (1, 0), 4: (2, 0), 5: (1, 2), 6: (0, 2), 7: (2, 1), 8: (2, 2)}
# Getting a all labelings for the graph +hh+c+g+g+e@.g6
